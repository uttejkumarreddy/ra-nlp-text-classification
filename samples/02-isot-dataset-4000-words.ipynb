# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path_dataset = '/content/gdrive/MyDrive/ai-playground/ra-text-classification-spectrogram/datasets/isot-dataset-cleaned.csv'

# %%
import pandas as pd

df = pd.read_csv(path_dataset)

mask = (df['text'].str.len() >= 4000)
df4000 = df.loc[mask]

# %%
df4000.shape
# Out:
# (2763, 3)

# %%
len(df4000.loc[df['category'] == 1])
# Out:
# 1474

# %%
len(df4000.loc[df['category'] == 0])
# Out:
# 1289

# %%
df4000.to_csv('isot-dataset-cleaned-4000.csv')
# !cp isot-dataset-cleaned-4000.csv "/content/gdrive/MyDrive/ai-playground/ra-text-classification-spectrogram/datasets"
